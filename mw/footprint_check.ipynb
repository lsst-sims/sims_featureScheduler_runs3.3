# %%
import numpy as np
import healpy as hp
from no_high_blob import CustomAreaMap
import matplotlib.pylab as plt
# %matplotlib inline

# %%
nside=32
sky = CustomAreaMap(nside=nside, smc_radius=4, lmc_radius=6)
footprints_hp_array, labels = sky.return_maps()

# %%
hp.mollview(footprints_hp_array['r'])

# %%
hp.mollview(footprints_hp_array['r'])
